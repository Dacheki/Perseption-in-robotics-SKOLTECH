# %%
from IPython.display import Image

# %%
print('TASK 1 A')
Image("C:/Users/daria\Desktop\perseption\Problem_Set_3\PS3\photos\Task_1_A_res.png", width=320, height=240)
# Out:
# TASK 1 A

# %%
print('Code 1A')
Image("C:/Users\daria\Desktop\perseption\Problem_Set_3\PS3\photos\code_1A.png", width=320, height=240)
# Out:
# Code 1A

# %%
print('TASK 1 B')
Image("C:/Users\daria\Desktop\perseption\Problem_Set_3\PS3\photos\Task_1_B_res.png", width=320, height=240)
# Out:
# TASK 1 B

# %%
print('Code 1 B')
Image("C:/Users\daria\Desktop\perseption\Problem_Set_3\PS3\photos\code_1B.png", width=320, height=240)
# Out:
# Code 1 B

# %% [markdown]
# *TASK 1 C*

# %%
Image("C:/Users\daria\Desktop\perseption\Problem_Set_3\PS3\photos/task1_c_1.png", width=320, height=240)

# %%
Image("C:/Users\daria\Desktop\perseption\Problem_Set_3\PS3\photos/task_1_c_2.png", width=320, height=240)

# %%
print('code 1C')
Image("C:/Users\daria\Desktop\perseption\Problem_Set_3\PS3\photos/code_1C.png", width=320, height=240)
# Out:
# code 1C

# %% [markdown]
# *New function gives to us more information. Gauss-Newton add more ditails about estimation and poses of our robot*

# %% [markdown]
# *TASK 1 D-*

# %%
Image("C:/Users\daria\Desktop\perseption\Problem_Set_3\PS3\photos/Task_1_D.png", width=320, height=240)

# %%
print('Code 1D')
Image("C:/Users\daria\Desktop\perseption\Problem_Set_3\PS3\photos/code_1D.png", width=320, height=240)
# Out:
# Code 1D

# %%
Image("C:/Users\daria\Desktop\perseption\Problem_Set_3\PS3\photos/Task_1_EF.png", width=320, height=240)

# %% [markdown]
# *We can see that both results of calculation really very closed. So we can say that using automatic functions or manually it is on you*

# %%
print('Code task 1E-F')
Image("C:/Users\daria\Desktop\perseption\Problem_Set_3\PS3\photos/code_1_EF.png", width=320, height=240)
# Out:
# Code task 1E-F

# %% [markdown]
# *TASK2*

# %%
print('TASK 2A')
Image("C:/Users\daria\Desktop\perseption\Problem_Set_3\PS3\photos/error.png", width=320, height=240)
# Out:
# TASK 2A

# %%
print('TASK 2B')
Image("C:/Users\daria\Desktop\perseption\Problem_Set_3\PS3\photos/task2b.png", width=320, height=240)
# Out:
# TASK 2B

# %%
print('Code 2B')
Image("C:/Users\daria\Desktop\perseption\Problem_Set_3\PS3\photos/code2b.png", width=320, height=240)
# Out:
# Code 2B

# %%
print('TASK 2C')
Image("C:/Users\daria\Desktop\perseption\Problem_Set_3\PS3\photos/matrix_1.png", width=320, height=240)
# Out:
# TASK 2C

# %%
Image("C:/Users\daria\Desktop\perseption\Problem_Set_3\PS3\photos/matrix_2.png", width=320, height=240)

# %%
print('Code 2C')
Image("C:/Users\daria\Desktop\perseption\Problem_Set_3\PS3\photos/code2c.png", width=320, height=240)
# Out:
# Code 2C

# %% [markdown]
# *We can see relationships between states and factors. We can see that information matrix has more relations*

# %%
print('TASK 2D')
Image("C:/Users\daria\Desktop\perseption\Problem_Set_3\PS3\photos/iso.png", width=320, height=240)
# Out:
# TASK 2D

# %%
print('Code 2D')
Image("C:/Users\daria\Desktop\perseption\Problem_Set_3\PS3\photos/code2d.png", width=320, height=240)
# Out:
# Code 2D

# %%
print('TASK 2E')
Image("C:/Users\daria\Desktop\perseption\Problem_Set_3\PS3\photos/task2e.png", width=320, height=240)
# Out:
# TASK 2E

# %%
print('Code 2E')
Image("C:/Users\daria\Desktop\perseption\Problem_Set_3\PS3\photos/code2e.png", width=320, height=240)
# Out:
# Code 2E
